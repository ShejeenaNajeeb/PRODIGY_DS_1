# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pandas as pd
data = pd.read_csv('~/world_population1.csv')

# %%
data.head(10)
# Out:
#    Rank CCA3    Country/Territory           Capital      Continent      2022  \
# 0    36  AFG          Afghanistan             Kabul           Asia  41128771
# 1   138  ALB              Albania            Tirana         Europe   2842321
# 2    34  DZA              Algeria           Algiers         Africa  44903225
# 3   213  ASM       American Samoa         Pago Pago        Oceania     44273
# 4   203  AND              Andorra  Andorra la Vella         Europe     79824
# 5    42  AGO               Angola            Luanda         Africa  35588987
# 6   224  AIA             Anguilla        The Valley  North America     15857
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America     93763
# 8    33  ARG            Argentina      Buenos Aires  South America  45510318
# 9   140  ARM              Armenia           Yerevan           Asia   2780469
#
#        2020      2015      2010      2000      1990      1980      1970  \
# ...

# %%
df_population=data.drop(['Rank','CCA3','Capital','Continent','Area (km²)','Density (per km²)','Growth Rate','World Population Percentage'],axis = 1)

# %%
df_population.head()
# Out:
#   Country/Territory      2022      2020      2015      2010      2000  \
# 0       Afghanistan  41128771  38972230  33753499  28189672  19542982
# 1           Albania   2842321   2866849   2882481   2913399   3182021
# 2           Algeria  44903225  43451666  39543154  35856344  30774621
# 3    American Samoa     44273     46189     51368     54849     58230
# 4           Andorra     79824     77700     71746     71519     66097
#
#        1990      1980      1970
# 0  10694796  12486631  10752971
# 1   3295066   2941651   2324731
# 2  25518074  18739378  13795915
# 3     47818     32886     27075
# 4     53569     35611     19860

# %%
country_data.columns
# Out:
# Index(['Country/Territory', '2022', '2020', '2015', '2010', '2000', '1990',
#        '1980', '1970'],
#       dtype='object')

# %%
country = 'Afghanistan'

country_data = df_population[df_population['Country/Territory'] == country]

years = country_data.columns[1:]
population = country_data.iloc[:, 1:].values.flatten()

plt.figure(figsize=(5, 3))
plt.bar(years, population, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title(f'Population of {country} in Years')
# Out:
# Text(0.5, 1.0, 'Population of Afghanistan in Years')

# %%
plt.hist(population, bins=20, color='skyblue', edgecolor='black')
plt.show()
